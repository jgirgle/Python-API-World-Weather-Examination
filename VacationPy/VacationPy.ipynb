# %%
pip install gmaps
# Out:
# Processing /Users/girgs/Library/Caches/pip/wheels/30/bd/87/d0d731ee712c34a4d6bace8b1dbf8c8932e22a1625b4a55be4/gmaps-0.9.0-py2.py3-none-any.whl
# Requirement already satisfied: ipython>=5.3.0 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from gmaps) (7.19.0)
# Requirement already satisfied: traitlets>=4.3.0 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from gmaps) (5.0.5)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from gmaps) (7.5.1)
# Requirement already satisfied: six in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from gmaps) (1.15.0)
# Collecting geojson>=2.0.0
#   Using cached geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: decorator in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (4.4.2)
# Requirement already satisfied: jedi>=0.10 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.17.1)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.1.0)
# Requirement already satisfied: pickleshare in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: backcall in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (3.0.8)
# Requirement already satisfied: setuptools>=18.5 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (50.3.1.post20201107)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (4.8.0)
# Requirement already satisfied: pygments in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.3.0->gmaps) (2.7.2)
# Requirement already satisfied: ipython-genutils in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from traitlets>=4.3.0->gmaps) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->gmaps) (5.0.8)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->ipython>=5.3.0->gmaps) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=5.3.0->gmaps) (0.6.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: jupyter-core in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.6.3)
# Requirement already satisfied: jupyter-client in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.7)
# Requirement already satisfied: tornado>=4.2 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.0.4)
# Requirement already satisfied: notebook>=4.4.1 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.1.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (20.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (19.0.2)
# Requirement already satisfied: jinja2 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.2)
# Requirement already satisfied: terminado>=0.8.3 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.1)
# Requirement already satisfied: prometheus-client in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.0)
# Requirement already satisfied: nbconvert in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.7)
# Requirement already satisfied: argon2-cffi in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: Send2Trash in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: defusedxml in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: testpath in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: bleach in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.2.1)
# Requirement already satisfied: cffi>=1.0.0 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.3)
# Requirement already satisfied: nest-asyncio in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: async-generator in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: packaging in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.4)
# Requirement already satisfied: webencodings in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: pycparser in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/girgs/opt/anaconda3/lib/python3.8/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)
# Installing collected packages: geojson, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
import time

# Import API key
from config import g_key

# %%
weather_data = pd.read_csv("../WeatherPy/output_data/cities.csv")
weather_data
# Out:
#                   City  Cloudiness Country        Date  Humidity      Lat  \
# 0            Bundaberg          22      AU  1614107869        88 -24.8500
# 1    Saint Paul Harbor           1      US  1614107869        68  57.7900
# 2           Nikolskoye          90      RU  1614107869        79  59.7035
# 3           Deputatsky          54      RU  1614107870        81  69.3000
# 4             Murupara          24      NZ  1614107870        98 -38.4667
# ..                 ...         ...     ...         ...       ...      ...
# 567     Saint-François           0      FR  1614108048        67  46.4154
# 568    Havre-St-Pierre          90      CA  1614108048        86  50.2334
# 569              Khovd          43      MN  1614108048        73  48.0056
# 570          Panzhihua           0      CN  1614108049        52  26.5851
# 571          Boguchany          99      RU  1614108049        98  58.3814
#
#           Lng  Max Temp  Wind Speed
# 0    152.3500     75.99        5.75
# 1   -152.4072     21.20        5.75
# 2     30.7861     12.20       11.18
# 3    139.9000    -29.40        2.68
# 4    176.7000     62.01        1.21
# ..        ...       ...         ...
# 567    3.9054     55.40        4.61
# 568  -63.5986     28.40       14.97
# 569   91.6419     20.64        5.75
# 570  101.7128     48.99        0.38
# 571   97.4531    -15.09        2.80
#
# [572 rows x 9 columns]

# %%
# Configure gmaps
gmaps.configure(api_key=g_key)

# Store latitude and longitude in locations
locations = weather_data[["Lat", "Lng"]]

# Store Humidity in humidity
humidity = weather_data["Humidity"]

# %%
# Plot Heatmap
fig = gmaps.figure(center=(46.0, -5.0), zoom_level=2)
max_intensity = np.max(humidity)

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights = humidity, dissipating=False, max_intensity=100, point_radius=3)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
max_intensity
# Out:
# 100

# %%
# Narrow down the cities with wind speed less than 10 mph, cloudiness equals to 0 and max temp between 60 and 80
narrowed_city_df = weather_data.loc[(weather_data["Wind Speed"] <= 10) & (weather_data["Cloudiness"] == 0) & \
                                   (weather_data["Max Temp"] >= 70) & (weather_data["Max Temp"] <= 80)].dropna()

narrowed_city_df
# Out:
#                City  Cloudiness Country        Date  Humidity      Lat  \
# 24           Najrān           0      SA  1614107876        33  17.4924
# 25   Saint-Philippe           0      RE  1614107876        69 -21.3585
# 43       Bhikangaon           0      IN  1614107881        18  21.8667
# 69           Mulegé           0      MX  1614107893        18  26.8833
# 80      Venkatagiri           0      IN  1614107896        76  13.9667
# 115        Tessalit           0      ML  1614107909        18  20.1986
# 131  Guerrero Negro           0      MX  1614107913        17  27.9769
# 167      Port Blair           0      IN  1614107923        67  11.6667
# 184       Carnarvon           0      AU  1614107929        83 -24.8667
# 191         Chicama           0      PE  1614107931        78  -7.8447
# 233     Bhubaneswar           0      IN  1614107702        83  20.2333
# 235           Na Wa           0      TH  1614107944        46  17.4897
# 239          Chokwé           0      MZ  1614107945        84 -24.5333
# 247    Saint-Pierre           0      RE  1614107949        69 -21.3393
# 290        Mācherla           0      IN  1614107959        68  16.4833
# 329           Kidal           0      ML  1614107971        15  18.4411
# 388         Salalah           0      OM  1614107988        73  17.0151
# 419       Burhānpur           0      IN  1614107995        17  21.3000
# 426         Bertoua           0      CM  1614107998        26   4.5833
# 437       Tcholliré           0      CM  1614107788        14   8.4022
# 441             Sur           0      OM  1614108002        48  22.5667
# 456         Larkana           0      PK  1614108009        68  27.5551
# 484          Sindgi           0      IN  1614108018        20  16.9167
# 505        Araouane           0      ML  1614108027         9  18.9048
# 530     Nacogdoches           0      US  1614108033        39  31.6002
# 539        Sakaraha           0      MG  1614108036        61 -22.9000
# 549     Maïné Soroa           0      NE  1614108039        13  13.2114
#
#           Lng  Max Temp  Wind Speed
# 24    44.1277     71.60        2.80
# 25    55.7679     78.80        5.75
# 43    75.9500     77.04        3.11
# 69  -111.9833     75.99        7.90
# 80    79.5833     71.20        3.74
# 115    1.0114     72.70        5.48
# 131 -114.0611     75.36        2.33
# 167   92.7500     76.64        1.57
# 184  113.6333     77.00        8.05
# 191  -79.1469     73.40        8.05
# 233   85.8333     71.60        4.61
# 235  104.1006     73.96        7.54
# 239   32.9833     74.93        8.50
# 247   55.4781     78.80        5.75
# 290   79.4333     73.63        4.59
# 329    1.4078     75.07        9.57
# 388   54.0924     75.20        2.30
# 419   76.2333     75.96        0.98
# 426   13.6833     75.97        1.57
# 437   14.1698     79.41        2.62
# 441   59.5289     73.74        6.49
# 456   68.2141     71.60        5.01
# 484   76.2333     73.53        8.81
# 505   -3.5265     76.96        6.17
# 530  -94.6335     73.99        4.00
# 539   44.5333     76.46        6.80
# 549   12.0241     71.67        8.16

# %%
# Create a hotel_df
hotel_df = narrowed_city_df.loc[:,["City","Country", "Lat", "Lng"]]

# Add a "Hotel Name" column to the DataFrame.
hotel_df["Hotel Name"] = ""

# Display the result
hotel_df
# Out:
#                City Country      Lat       Lng Hotel Name
# 24           Najrān      SA  17.4924   44.1277
# 25   Saint-Philippe      RE -21.3585   55.7679
# 43       Bhikangaon      IN  21.8667   75.9500
# 69           Mulegé      MX  26.8833 -111.9833
# 80      Venkatagiri      IN  13.9667   79.5833
# 115        Tessalit      ML  20.1986    1.0114
# 131  Guerrero Negro      MX  27.9769 -114.0611
# 167      Port Blair      IN  11.6667   92.7500
# 184       Carnarvon      AU -24.8667  113.6333
# 191         Chicama      PE  -7.8447  -79.1469
# 233     Bhubaneswar      IN  20.2333   85.8333
# 235           Na Wa      TH  17.4897  104.1006
# 239          Chokwé      MZ -24.5333   32.9833
# 247    Saint-Pierre      RE -21.3393   55.4781
# 290        Mācherla      IN  16.4833   79.4333
# 329           Kidal      ML  18.4411    1.4078
# 388         Salalah      OM  17.0151   54.0924
# 419       Burhānpur      IN  21.3000   76.2333
# 426         Bertoua      CM   4.5833   13.6833
# 437       Tcholliré      CM   8.4022   14.1698
# 441             Sur      OM  22.5667   59.5289
# 456         Larkana      PK  27.5551   68.2141
# 484          Sindgi      IN  16.9167   76.2333
# 505        Araouane      ML  18.9048   -3.5265
# 530     Nacogdoches      US  31.6002  -94.6335
# 539        Sakaraha      MG -22.9000   44.5333
# 549     Maïné Soroa      NE  13.2114   12.0241

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params = {"type" : "hotel",
          "keyword" : "hotel",
          "radius" : 5000,
          "key" : g_key}

# %%
for index, row in hotel_df.iterrows():
    # get city name, lat, lnt from df
    lat = row["Lat"]
    lng = row["Lng"]
    city_name = row["City"]
    
    # add keyword to params dict
    params["location"] = f"{lat},{lng}"

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {city_name}.")
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    # save the hotel name to dataframe
    try:
        print(f"Closest hotel in {city_name} is {results[0]['name']}.")
        hotel_df.loc[index, "Hotel Name"] = results[0]['name']

    # if there is no hotel available, show missing field
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
    
    # Wait 1 sec to make another api request to avoid SSL Error
    time.sleep(1)

# Print end of search once searching is completed
print("-------End of Search-------")
# Out:
# Retrieving Results for Index 24: Najrān.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 25: Saint-Philippe.
# Closest hotel in Saint-Philippe is Les Embruns Du Baril.
# ------------
# Retrieving Results for Index 43: Bhikangaon.
# Closest hotel in Bhikangaon is khadwa road.
# ------------
# Retrieving Results for Index 69: Mulegé.
# Closest hotel in Mulegé is Hotel Serenidad.
# ------------
# Retrieving Results for Index 80: Venkatagiri.
# Closest hotel in Venkatagiri is Hotel rayal Grand.
# ------------
# Retrieving Results for Index 115: Tessalit.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 131: Guerrero Negro.
# Closest hotel in Guerrero Negro is Hotel TerraSal.
# ------------
# Retrieving Results for Index 167: Port Blair.
# Closest hotel in Port Blair is Welcomhotel Bay Island Port Blair.
# ------------
# Retrieving Results for Index 184: Carnarvon.
# Closest hotel in Carnarvon is Carnarvon Sea Change Apartments.
# ------------
# Retrieving Results for Index 191: Chicama.
# Closest hotel in Chicama is Balihai Bungalows.
# ------------
# Retrieving Results for Index 233: Bhubaneswar.
# Closest hotel in Bhubaneswar is Hotel Kalinga Ashok.
# ------------
# Retrieving Results for Index 235: Na Wa.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 239: Chokwé.
# Closest hotel in Chokwé is Hotel Sorriso de Caridade.
# ------------
# Retrieving Results for Index 247: Saint-Pierre.
# Closest hotel in Saint-Pierre is Le Battant Des Lames.
# ------------
# Retrieving Results for Index 290: Mācherla.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 329: Kidal.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 388: Salalah.
# Closest hotel in Salalah is HYATT SALALAH HOTEL.
# ------------
# Retrieving Results for Index 419: Burhānpur.
# Closest hotel in Burhānpur is Utsav Hotel And Resorts.
# ------------
# Retrieving Results for Index 426: Bertoua.
# Closest hotel in Bertoua is MANSA HOTEL.
# ------------
# Retrieving Results for Index 437: Tcholliré.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 441: Sur.
# Closest hotel in Sur is Sur Plaza Hotel.
# ------------
# Retrieving Results for Index 456: Larkana.
# Closest hotel in Larkana is Paris Inn Hotel.
# ------------
# Retrieving Results for Index 484: Sindgi.
# Closest hotel in Sindgi is Hotel Arpita Lodge.
# ------------
# Retrieving Results for Index 505: Araouane.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 530: Nacogdoches.
# Closest hotel in Nacogdoches is The Fredonia Hotel & Convention Center.
# ------------
# Retrieving Results for Index 539: Sakaraha.
# Closest hotel in Sakaraha is Hôtel 2000.
# ------------
# Retrieving Results for Index 549: Maïné Soroa.
# Missing field/result... skipping.
# ------------
# -------End of Search-------

# %%
# Display the hotel dataframe
hotel_df
# Out:
#                City Country      Lat       Lng  \
# 24           Najrān      SA  17.4924   44.1277
# 25   Saint-Philippe      RE -21.3585   55.7679
# 43       Bhikangaon      IN  21.8667   75.9500
# 69           Mulegé      MX  26.8833 -111.9833
# 80      Venkatagiri      IN  13.9667   79.5833
# 115        Tessalit      ML  20.1986    1.0114
# 131  Guerrero Negro      MX  27.9769 -114.0611
# 167      Port Blair      IN  11.6667   92.7500
# 184       Carnarvon      AU -24.8667  113.6333
# 191         Chicama      PE  -7.8447  -79.1469
# 233     Bhubaneswar      IN  20.2333   85.8333
# 235           Na Wa      TH  17.4897  104.1006
# 239          Chokwé      MZ -24.5333   32.9833
# 247    Saint-Pierre      RE -21.3393   55.4781
# 290        Mācherla      IN  16.4833   79.4333
# 329           Kidal      ML  18.4411    1.4078
# 388         Salalah      OM  17.0151   54.0924
# 419       Burhānpur      IN  21.3000   76.2333
# 426         Bertoua      CM   4.5833   13.6833
# 437       Tcholliré      CM   8.4022   14.1698
# 441             Sur      OM  22.5667   59.5289
# 456         Larkana      PK  27.5551   68.2141
# 484          Sindgi      IN  16.9167   76.2333
# 505        Araouane      ML  18.9048   -3.5265
# 530     Nacogdoches      US  31.6002  -94.6335
# 539        Sakaraha      MG -22.9000   44.5333
# 549     Maïné Soroa      NE  13.2114   12.0241
#
#                                  Hotel Name
# 24
# 25                     Les Embruns Du Baril
# 43                              khadwa road
# 69                          Hotel Serenidad
# 80                        Hotel rayal Grand
# 115
# 131                          Hotel TerraSal
# 167       Welcomhotel Bay Island Port Blair
# 184         Carnarvon Sea Change Apartments
# 191                       Balihai Bungalows
# 233                     Hotel Kalinga Ashok
# 235
# 239               Hotel Sorriso de Caridade
# 247                    Le Battant Des Lames
# 290
# 329
# 388                     HYATT SALALAH HOTEL
# 419                 Utsav Hotel And Resorts
# 426                             MANSA HOTEL
# 437
# 441                         Sur Plaza Hotel
# 456                         Paris Inn Hotel
# 484                      Hotel Arpita Lodge
# 505
# 530  The Fredonia Hotel & Convention Center
# 539                              Hôtel 2000
# 549

# %%
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
#hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer and info box content ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content = hotel_info)

# Add the layer to the map
fig.add_layer(markers)

# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
